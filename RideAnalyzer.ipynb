# %%
import fitdecode

with fitdecode.FitReader('FitFiles\20260716054447_10886424.fit') as fit:
    for frame in fit:
        # The yielded frame object is of one of the following types:
        # * fitdecode.FitHeader (FIT_FRAME_HEADER)
        # * fitdecode.FitDefinitionMessage (FIT_FRAME_DEFINITION)
        # * fitdecode.FitDataMessage (FIT_FRAME_DATA)
        # * fitdecode.FitCRC (FIT_FRAME_CRC)

        if frame.frame_type == fitdecode.FIT_FRAME_DATA:
            # Here, frame is a FitDataMessage object.
            # A FitDataMessage object contains decoded values that
            # are directly usable in your script logic.
            print(frame.name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import fitdecode
#       2
# ----> 3 with fitdecode.FitReader('FitFiles\20260716054447_10886424.fit') as fit:
#       4     for frame in fit:
#       5         # The yielded frame object is of one of the following types:
#       6         # * fitdecode.FitHeader (FIT_FRAME_HEADER)
#
# File c:\Users\olive\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\fitdecode\reader.py:209, in FitReader.__init__(self, fileish, processor, check_crc, error_handling, keep_raw_chunks, data_bag)
#     207     self._fd_owned = False
#     208 elif isinstance(fileish, str) or hasattr(fileish, '__fspath__'):
# --> 209     self._fd = open(fileish, mode='rb')
#     210     self._fd_owned = True
#     211 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'FitFiles\x8260716054447_10886424.fit'
